# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/student_exam_scores.csv')

# %% [markdown]
# # 1. Exploratory Data Analysis
#
# ## Objectif :
# - Comprendre du mieux possible nos données (un petit pas en avant vaut mieux qu'un grand pas en arriere)
# - Développer une premiere stratégie de modélisation
#
# ## Checklist de base
# #### Analyse de Forme :
# - **variable target** : exam_score
# - **lignes et colonnes** : 200, 6
# - **types de variables** : 5 quantitative, 1 qualitative (mais il s'agit de l'id de l'étudiant, à supprimer pour l'apprentissage)
# - **Analyse des valeurs manquantes** : aucun NaN
#
# #### Analyse de Fond :
# - **Visualisation de la target** :
# - **Signification des variables** :
# - **Relation Variables / Target** :

# %%
df.head()
# Out:
#   student_id  hours_studied  sleep_hours  attendance_percent  previous_scores  \
# 0       S001            8.0          8.8                72.1               45
# 1       S002            1.3          8.6                60.7               55
# 2       S003            4.0          8.2                73.7               86
# 3       S004            3.5          4.8                95.1               66
# 4       S005            9.1          6.4                89.8               71
#
#    exam_score
# 0        30.2
# 1        25.0
# 2        35.8
# 3        34.0
# 4        40.3

# %%
df.describe()
# Out:
#        hours_studied  sleep_hours  attendance_percent  previous_scores  \
# count     200.000000   200.000000          200.000000       200.000000
# mean        6.325500     6.622000           74.830000        66.800000
# std         3.227317     1.497138           14.249905        15.663869
# min         1.000000     4.000000           50.300000        40.000000
# 25%         3.500000     5.300000           62.200000        54.000000
# 50%         6.150000     6.700000           75.250000        67.500000
# 75%         9.000000     8.025000           87.425000        80.000000
# max        12.000000     9.000000          100.000000        95.000000
#
#        exam_score
# count  200.000000
# mean    33.955000
# std      6.789548
# min     17.100000
# 25%     29.500000
# 50%     34.050000
# 75%     38.750000
# max     51.300000

# %%
df.shape
# Out:
# (200, 6)

# %%
df.dtypes.value_counts() # On peux aussi rajouter .plot.pie() pour visualiser les proportions
# Out:
# float64    4
# object     1
# int64      1
# Name: count, dtype: int64

# %%
import seaborn as sns

# %%
sns.pairplot(df)
plt.show()
